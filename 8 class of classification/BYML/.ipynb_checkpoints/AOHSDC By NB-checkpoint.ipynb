# %%
#read the dataset/import the file
import pandas as pd
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import  re
import nltk
from gensim.models import Word2Vec
import gensim
import pandas as pd
from sklearn.model_selection import train_test_split
import tensorflow as tf 
from keras.models import load_model # saving model for later use
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\gensim\utils.py:1167: UserWarning: detected Windows; aliasing chunkize to chunkize_serial
#   warnings.warn("detected Windows; aliasing chunkize to chunkize_serial")

# %%
import pandas as pd
xl = pd.ExcelFile("final_datasets8.xlsx")
df = xl.parse( header=None, names=['ID','Level','Date','Label','Msg'], encoding='utf-8')
df
# Out:
#                                     ID  Level       Date  Label  \
# 0                      450812019270046      1  20/1/2021      1
# 1                      451178209233427      1  20/1/2021      1
# 2                      451092299242018      1  20/1/2021      1
# 3                      450937722590809      1  20/1/2021     10
# 4                      451408632543718      1  20/1/2021      1
# ...                                ...    ...        ...    ...
# 12807  874138889673855_874148553006222      2  26/4/2021     40
# 12808  874138889673855_874148726339538      2  26/4/2021     40
# 12809  874138889673855_874152466339164      2  26/4/2021     40
# 12810  874138889673855_874152919672452      2  26/4/2021     40
# 12811  874138889673855_874152956339115      2  26/4/2021     40
#
#                                                      Msg
# 0      Durbi garee kanaa hundishee akka waan durbumma...
# 1      Durbif gaararraan waanuma argitetti bifasheef ...
# 2      Durbummaa namni qabu hundi gagamaa dha. Adduny...
# 3                        Durbi safuu beektu keessa kooti
# 4      Durbummaa mataan haxxifannaan Hiikatu na jibbi...
# ...                                                  ...
# 12807              CAALAA keenya dhugumaan caalaadha ati
# 12808  Dhugaan karaatti hin haftu caaliyyee   jabaadh...
# 12809       Nuuf buli  wan gumaachitu  hin dhabin sanyii
# 12810  Leenca keenya dhugaa keeti jajjabee koo ❤️💚❤️💘💘💘💘
# 12811                  Nuuf jiraadhu leenca keenya❤❤❤❤❤❤
#
# [12812 rows x 5 columns]

# %%
df.isnull().sum()
# Out:
# ID       0
# Level    0
# Date     0
# Label    0
# Msg      0
# dtype: int64

# %%
##to know the number of each class data
df['Label'].value_counts()
# Out:
# 3     1898
# 10    1741
# 4     1714
# 20    1559
# 1     1556
# 2     1468
# 40    1455
# 30    1421
# Name: Label, dtype: int64

# %%
#data set Illustration by pie chart 
exp_vals = [  1556, 1468,  1898, 1714, 1741, 1559, 1421, 1455]
exp_labels = ["Gender Related Hate","Religion Related Hate","Race Related Hate","Offensive Related Hate","Gender Related Free","Relgion Related Free ","Race Related Free","offensive Related Free"]
plt.axis("equal")
plt.pie(exp_vals,labels=exp_labels, shadow=True, autopct='%1.1f%%',radius=1)
plt.show()

# %%
df
# Out:
#                                     ID  Level       Date  Label  \
# 0                      450812019270046      1  20/1/2021      1
# 1                      451178209233427      1  20/1/2021      1
# 2                      451092299242018      1  20/1/2021      1
# 3                      450937722590809      1  20/1/2021     10
# 4                      451408632543718      1  20/1/2021      1
# ...                                ...    ...        ...    ...
# 12807  874138889673855_874148553006222      2  26/4/2021     40
# 12808  874138889673855_874148726339538      2  26/4/2021     40
# 12809  874138889673855_874152466339164      2  26/4/2021     40
# 12810  874138889673855_874152919672452      2  26/4/2021     40
# 12811  874138889673855_874152956339115      2  26/4/2021     40
#
#                                                      Msg
# 0      Durbi garee kanaa hundishee akka waan durbumma...
# 1      Durbif gaararraan waanuma argitetti bifasheef ...
# 2      Durbummaa namni qabu hundi gagamaa dha. Adduny...
# 3                        Durbi safuu beektu keessa kooti
# 4      Durbummaa mataan haxxifannaan Hiikatu na jibbi...
# ...                                                  ...
# 12807              CAALAA keenya dhugumaan caalaadha ati
# 12808  Dhugaan karaatti hin haftu caaliyyee   jabaadh...
# 12809       Nuuf buli  wan gumaachitu  hin dhabin sanyii
# 12810  Leenca keenya dhugaa keeti jajjabee koo ❤️💚❤️💘💘💘💘
# 12811                  Nuuf jiraadhu leenca keenya❤❤❤❤❤❤
#
# [12812 rows x 5 columns]

# %%
df.groupby('Label').describe()
# Out:
#         Level
#         count      mean       std  min  25%  50%  75%  max
# Label
# 1      1556.0  1.277635  0.447976  1.0  1.0  1.0  2.0  2.0
# 2      1468.0  1.369891  0.482939  1.0  1.0  1.0  2.0  2.0
# 3      1898.0  1.257640  0.437450  1.0  1.0  1.0  2.0  2.0
# 4      1714.0  2.000000  0.000000  2.0  2.0  2.0  2.0  2.0
# 10     1741.0  1.103389  0.304554  1.0  1.0  1.0  1.0  2.0
# 20     1559.0  1.661321  0.473412  1.0  1.0  2.0  2.0  2.0
# 30     1421.0  1.046446  0.210523  1.0  1.0  1.0  1.0  2.0
# 40     1455.0  2.000000  0.000000  2.0  2.0  2.0  2.0  2.0

# %%
df.drop(['ID','Level','Date'],axis='columns',inplace=True)
df
# Out:
#        Label                                                Msg
# 0          1  Durbi garee kanaa hundishee akka waan durbumma...
# 1          1  Durbif gaararraan waanuma argitetti bifasheef ...
# 2          1  Durbummaa namni qabu hundi gagamaa dha. Adduny...
# 3         10                    Durbi safuu beektu keessa kooti
# 4          1  Durbummaa mataan haxxifannaan Hiikatu na jibbi...
# ...      ...                                                ...
# 12807     40              CAALAA keenya dhugumaan caalaadha ati
# 12808     40  Dhugaan karaatti hin haftu caaliyyee   jabaadh...
# 12809     40       Nuuf buli  wan gumaachitu  hin dhabin sanyii
# 12810     40  Leenca keenya dhugaa keeti jajjabee koo ❤️💚❤️💘💘💘💘
# 12811     40                  Nuuf jiraadhu leenca keenya❤❤❤❤❤❤
#
# [12812 rows x 2 columns]

# %%
df['Label1']=df['Label']
df
# Out:
#        Label                                                Msg  Label1
# 0          1  Durbi garee kanaa hundishee akka waan durbumma...       1
# 1          1  Durbif gaararraan waanuma argitetti bifasheef ...       1
# 2          1  Durbummaa namni qabu hundi gagamaa dha. Adduny...       1
# 3         10                    Durbi safuu beektu keessa kooti      10
# 4          1  Durbummaa mataan haxxifannaan Hiikatu na jibbi...       1
# ...      ...                                                ...     ...
# 12807     40              CAALAA keenya dhugumaan caalaadha ati      40
# 12808     40  Dhugaan karaatti hin haftu caaliyyee   jabaadh...      40
# 12809     40       Nuuf buli  wan gumaachitu  hin dhabin sanyii      40
# 12810     40  Leenca keenya dhugaa keeti jajjabee koo ❤️💚❤️💘💘💘💘      40
# 12811     40                  Nuuf jiraadhu leenca keenya❤❤❤❤❤❤      40
#
# [12812 rows x 3 columns]

# %%
df.drop(['Label'],axis='columns',inplace=True)
df
# Out:
#                                                      Msg  Label1
# 0      Durbi garee kanaa hundishee akka waan durbumma...       1
# 1      Durbif gaararraan waanuma argitetti bifasheef ...       1
# 2      Durbummaa namni qabu hundi gagamaa dha. Adduny...       1
# 3                        Durbi safuu beektu keessa kooti      10
# 4      Durbummaa mataan haxxifannaan Hiikatu na jibbi...       1
# ...                                                  ...     ...
# 12807              CAALAA keenya dhugumaan caalaadha ati      40
# 12808  Dhugaan karaatti hin haftu caaliyyee   jabaadh...      40
# 12809       Nuuf buli  wan gumaachitu  hin dhabin sanyii      40
# 12810  Leenca keenya dhugaa keeti jajjabee koo ❤️💚❤️💘💘💘💘      40
# 12811                  Nuuf jiraadhu leenca keenya❤❤❤❤❤❤      40
#
# [12812 rows x 2 columns]

# %% [markdown]
# # 1. Data Pre-processing

# %%
# WORD COUNT:
df['word_count'] = df['Msg'].apply(lambda x : len(str(x).split()))
df.head(450)
# Out:
#                                                    Msg  Label1  word_count
# 0    Durbi garee kanaa hundishee akka waan durbumma...       1          11
# 1    Durbif gaararraan waanuma argitetti bifasheef ...       1           7
# 2    Durbummaa namni qabu hundi gagamaa dha. Adduny...       1          16
# 3                      Durbi safuu beektu keessa kooti      10           5
# 4    Durbummaa mataan haxxifannaan Hiikatu na jibbi...       1           6
# ..                                                 ...     ...         ...
# 445  Shamarri durbummaa hin qabne farda luugama hin...       1           8
# 446  Jecha obboleettii keetin hin jenne obboloota b...      10           9
# 447  Durbuma Funyaan ishee hamma mokoronii ishee xi...       1          11
# 448  Shamarri dhaqna hin qabanne mi'a yookiin qodaa...       1           8
# 449              Durbi kaaffee barte bultiif hin taatu       1           6
#
# [450 rows x 3 columns]

# %%
# Convert to Lower Case : 
df['Msg'] = df['Msg'].apply(lambda x : x.lower())
df['Msg'].head(2)
df
# Out:
#                                                      Msg  Label1  word_count
# 0      durbi garee kanaa hundishee akka waan durbumma...       1          11
# 1      durbif gaararraan waanuma argitetti bifasheef ...       1           7
# 2      durbummaa namni qabu hundi gagamaa dha. adduny...       1          16
# 3                        durbi safuu beektu keessa kooti      10           5
# 4      durbummaa mataan haxxifannaan hiikatu na jibbi...       1           6
# ...                                                  ...     ...         ...
# 12807              caalaa keenya dhugumaan caalaadha ati      40           5
# 12808  dhugaan karaatti hin haftu caaliyyee   jabaadh...      40           8
# 12809       nuuf buli  wan gumaachitu  hin dhabin sanyii      40           7
# 12810  leenca keenya dhugaa keeti jajjabee koo ❤️💚❤️💘💘💘💘      40           7
# 12811                  nuuf jiraadhu leenca keenya❤❤❤❤❤❤      40           4
#
# [12812 rows x 3 columns]

# %%
#Removing any date format 
df["Msg"].replace(
    {'\d+[\/:\-]\d+[\/:\-\s]*[\dAaPpMm]*' : '', '\w+\s\d+[\,]\s\d+' : ''},
    regex=True,
    inplace=True,
    )

# %%
# Contaction to Expansion > can't TO can not ,you'll TO you will
contractions = { 
"fkn": "fakkeenya",
"ykn": "yookaan ",
"lakk.": "lakkoofsa",
"hub.": "hubachiisa",
"fbc": "faanaa broodkaastingi korporeet ",
"obn": "oromiyaa broodkaastingi neetwoork ",
"omn": "oromiyaa miidiyaa neetwoork ",
"fb": "feesbuukii",
"qar.": "qarshii",
"bill.": "billiyoona ",
"a.l.a": "akka lakkoofsa awurooppaa",
"a.l.i": "Akka Lakkoofsa Itoophiyaa",
"kkf": "kan kana fakkaatan",
"kkf.": "kan kana fakkaatan",    
"m/b": "mana barumsaa",
"prof.": "pirofeesara",
"dr.": "dooctar",
"dn.": "daaqon",
"i/g": "itti gaafatamaa",
"ob.": "obbo",
"obb.": "obbo",
"m/murtii": "mana Murtii",
"hosp.": "hospitaala",
"mm.": "muumee Ministeeraa",
"dh.k.d": "dhaloota kiristoosin duura",
"dh.k.b": " dhaloota kiristoosin booda",
"h/bulaa": "hoorsisee Bulaa",
"q/bulaa": "qoonaan bulaa",
"A.B.O": "adda Bilisa baasa uummata oromoo ",
"pmns": "prezdaantii mootummaa naannoo somaalee",
"pmno": "prezdaantii mootummaa naannoo oromiyaa",  
"pmna": "prezdaantii mootummaa naannoo amaaraa",   
"pmng": "prezdaantii mootummaa naannoo gambeellaa", 
"pmnbg": "prezdaantii mootummaa naannoo benishaangul gumuuz",
"a.s.w": "assalaamu'aleykum warahmatullahi wabarakaatuhu",
"asw": "assalaamu'aleykum warahmatullahi wabarakaatuhu",    
"jzk": "jazakallah ",
"s.w.a": "sallallaahu aleeyhi wasallam ",    
"alh": "allah",
"b.b.o": "biiroo barnoota oromiyaa",
"k.b.r": " kolleejjii barsiisota roobee ",
"k.b.a": " kolleejjii barsiisota asallaa ",    
"k.b.j": " kolleejjii barsiisota jimmaa ",   
"k.b.y": " kolleejjii barsiisota yaa'aballoo ",  
"k.b.s": " kolleejjii barsiisota sabbataa ",       
"db.f.o": "dhaabbata fayyaa oromiyaa ",
"m.n.o": "mootummaa naannoo oromiyaa",
"mno": "mootummaa naannoo oromiyaa",    
"r.i.b": "raayyaa ittisa biyyaa",
"a.b.u.t": "adda bilisa baasa uummata tigraayi ",
"t.p.l.f": "adda bilisa baasa uummata tigraayi ",    
"kk": "kkk",
"kkk" :"kkk",
"kkkk":"kkk",
"kkkkk":"kkk",
"kkkkkk":"kkk",
"kkkkkkk":"kkk",
"hh":"hhh" ,
"hhh":"hhh",
"hhhh":"hhh",
"hhhhh":"hhh",
"hhhhhh":"hhh",
"hhhhhhh":"hhh",
"wow":"wow",
"woow":"wow",
"wooow":"wow",
"woooow":"wow",
"wooooow":"wow",
"woooooow":"wow",
"www":"wow",
"wwhoo":"wow",
"ohh":"ooh",
"oohh":"ooh",
"oohhh":"ooh",
"ohh":"ooh",
"oohh":"ooh",
"ooohhh":"ooh",
"akkka":"akka",    
"uuf":"uuf",
"uuuf":"uuf",
"uuuuf":"uuf",
"uuuuuf":"uuf",
"uuuuuuf":"uuf",
"uuff":"uuf",
"uuff":"uuf",
"uufff":"uuf",
"uuffff":"uuf",
"uufffff":"uuf",
"uuffffff":"uuf ",
"uffee":"uffee",
"uffeee":"uffee",
"ufee":"uffee",
"ufeeee":"uffee",
"baay'ee": "baayyee",
"ja'a": "jaha ",
"keecha" : "keessa",
"har'a": "harra ",
"ajaa'iba":" ajaayiba ",
"qeeyroo":"qeerroo ",
"bal'aa": "ballaa ",
"qal'oo" : "qalloo",
"keeysa":"keessa",
"worra": "warra",
"mul'ta":"Mullata" ,
"xoophiyaa":"itoophiyaa",
"yuunibaristii":"yuunivarsiitii" ,
"wonti" :" wanti",
"umrii" :" umurii",
"waa'ee" :"waayee",
"re'ee" :"rehee",
"dhalaa": "dubara",
"keeysan" :" keessan",
"qur'aana" :" quraana",
"sheeyxana" :" seexana",
"ba'e":"bahe",
"wahii":"wayii",
"macaafa":"kitaaba",
"dhagahuu":"dhaga'uu",
"dhageeysa":"dhageecha" ,
"rabbi":"waaqa",
"beetti":"beekti",
"fuundura" :" fuuldura",
"keeysa" :"  keessa",
"olkaa'uu": "olkaawuu",
"obboleeysa": "obbolessa",
"wal'aalaa":"wallaalaa" ,  
"wal'aalaan":"wallaalaan"   
}
def cont_to_exp(x):
    if type(x) is str:
        for key in contractions:
            value = contractions[key]
            x = x.replace(key, value)
        return x
    else:
        return x
df['Msg'] = df['Msg'].apply(lambda x : cont_to_exp(x))

# %%
df
# Out:
#                                                      Msg  Label1  word_count
# 0      durbi garee kanaa hundishee akka waan durbumma...       1          11
# 1      durbif gaararraan waanuma argitetti bifasheef ...       1           7
# 2      durbummaa namni qabu hundi gagamaa dha. adduny...       1          16
# 3                        durbi safuu beektu keessa kooti      10           5
# 4      durbummaa mataan haxxifannaan hiikatu na jibbi...       1           6
# ...                                                  ...     ...         ...
# 12807              caalaa keenya dhugumaan caalaadha ati      40           5
# 12808  dhugaan karaatti hin haftu caaliyyee   jabaadh...      40           8
# 12809       nuuf buli  wan gumaachitu  hin dhabin sanyii      40           7
# 12810  leenca keenya dhugaa keeti jajjabee koo ❤️💚❤️💘💘💘💘      40           7
# 12811                  nuuf jiraadhu leenca keenya❤❤❤❤❤❤      40           4
#
# [12812 rows x 3 columns]

# %%
# remove Institutional Email
df['Msg'] = df['Msg'].apply(lambda i : re.sub(r'([A-Za-z0-9+_]+\.[A-Za-z0-9+_]+@[A-Za-z0-9+_]+\.[A-Za-z0-9+_]+\.[A-Za-z0-9+_]+)','', i))

# %%
# Remove normal email
df['Msg'] = df['Msg'].apply(lambda i : re.sub(r'([A-Za-z0-9+_]+@[A-Za-z0-9+_]+\.[A-Za-z0-9+_]+)','', i))

# %%
df
# Out:
#                                                      Msg  Label1  word_count
# 0      durbi garee kanaa hundishee akka waan durbumma...       1          11
# 1      durbif gaararraan waanuma argitetti bifasheef ...       1           7
# 2      durbummaa namni qabu hundi gagamaa dha. adduny...       1          16
# 3                        durbi safuu beektu keessa kooti      10           5
# 4      durbummaa mataan haxxifannaan hiikatu na jibbi...       1           6
# ...                                                  ...     ...         ...
# 12807              caalaa keenya dhugumaan caalaadha ati      40           5
# 12808  dhugaan karaatti hin haftu caaliyyee   jabaadh...      40           8
# 12809       nuuf buli  wan gumaachitu  hin dhabin sanyii      40           7
# 12810  leenca keenya dhugaa keeti jajjabee koo ❤️💚❤️💘💘💘💘      40           7
# 12811                  nuuf jiraadhu leenca keenya❤❤❤❤❤❤      40           4
#
# [12812 rows x 3 columns]

# %%
# Remove URL
df['Msg'] = df['Msg'].apply(lambda i : re.sub(r'https?://[^\s<>"]+|www\.[^\s<>"]+','', i))
df.head()
# Out:
#                                                  Msg  Label1  word_count
# 0  durbi garee kanaa hundishee akka waan durbumma...       1          11
# 1  durbif gaararraan waanuma argitetti bifasheef ...       1           7
# 2  durbummaa namni qabu hundi gagamaa dha. adduny...       1          16
# 3                    durbi safuu beektu keessa kooti      10           5
# 4  durbummaa mataan haxxifannaan hiikatu na jibbi...       1           6

# %%
# Remove more than one white space 
df['Msg'] = df['Msg'].apply(lambda d : " ".join(d.split()))

# %%
# Remove HTML tags 
from bs4 import BeautifulSoup
df['Msg'] = df['Msg'].apply(lambda x : BeautifulSoup(x, 'lxml').get_text())

# %%
# Removing special charcter and Puncutation marks & number 
spec_chars = ["!","-",'"',"#","%","&","(",")", 
              "*","+",",","-",".","/",":",";","<",
              "=",">","?","@","[","\\","]","^","_",
            "`","{","|","}","~","–"]
for char in spec_chars:
    df['Msg'] = df['Msg'].str.replace(char, ' ')

# %%
# Replacing ’ with apostrophe(') this is not work pls find and replace from excell 
spec_chars3 = ["’"]
for chars in spec_chars3:
    df['Msg'] = df['Msg'].str.replace(chars, " ' ")

# %%
# remove Stop word 
read=open("stopword.txt",encoding='latin',mode='r')
readfirst=read.read()
def remove_stop_word(x):
    filtered_words = [word for word in x.split() if word not in readfirst]
    return " ".join(filtered_words)
df['Msg'] = df['Msg'].apply(lambda x : remove_stop_word(x))
df
# Out:
#                                                      Msg  Label1  word_count
# 0      durbi garee hundishee durbummaa qabduu dhiira ...       1          11
# 1      durbif gaararraan waanuma argitetti bifasheef ...       1           7
# 2      durbummaa namni qabu hundi gagamaa addunyaan m...       1          16
# 3                               durbi safuu beektu kooti      10           5
# 4      durbummaa mataan haxxifannaan hiikatu jibbisiisam       1           6
# ...                                                  ...     ...         ...
# 12807                         caalaa dhugumaan caalaadha      40           5
# 12808  dhugaan karaatti hin haftu caaliyyee jabaadhu ...      40           8
# 12809              buli wan gumaachitu hin dhabin sanyii      40           7
# 12810             leenca dhugaa keeti jajjabee ❤️💚❤️💘💘💘💘      40           7
# 12811                       jiraadhu leenca keenya❤❤❤❤❤❤      40           4
#
# [12812 rows x 3 columns]

# %%
df
# Out:
#                                                      Msg  Label1  word_count
# 0      durbi garee hundishee durbummaa qabduu dhiira ...       1          11
# 1      durbif gaararraan waanuma argitetti bifasheef ...       1           7
# 2      durbummaa namni qabu hundi gagamaa addunyaan m...       1          16
# 3                               durbi safuu beektu kooti      10           5
# 4      durbummaa mataan haxxifannaan hiikatu jibbisiisam       1           6
# ...                                                  ...     ...         ...
# 12807                         caalaa dhugumaan caalaadha      40           5
# 12808  dhugaan karaatti hin haftu caaliyyee jabaadhu ...      40           8
# 12809              buli wan gumaachitu hin dhabin sanyii      40           7
# 12810             leenca dhugaa keeti jajjabee ❤️💚❤️💘💘💘💘      40           7
# 12811                       jiraadhu leenca keenya❤❤❤❤❤❤      40           4
#
# [12812 rows x 3 columns]

# %%
# Removing Emoji
def remove_emoji(string):
    emoji_pattern = re.compile("["
                               u"\U0001F600-\U0001F64F"  # emoticons
                               u"\U0001F300-\U0001F5FF"  # symbols & pictographs
                               u"\U0001F680-\U0001F6FF"  # transport & map symbols
                               u"\U0001F1E0-\U0001F1FF"  # flags (iOS)
                               u"\U00002500-\U00002BEF"  # chinese char
                               u"\U00002702-\U000027B0"
                               u"\U00002702-\U000027B0"
                               u"\U000024C2-\U0001F251"
                               u"\U0001f926-\U0001f937"
                               u"\U00010000-\U0010ffff"
                               u"\u2640-\u2642"
                               u"\u2600-\u2B55"
                               u"\u200d"
                               u"\u23cf"
                               u"\u23e9"
                               u"\u231a"
                               u"\ufe0f"  # dingbats
                               u"\u3030"
                               "]+", flags=re.UNICODE)
    return emoji_pattern.sub(r'', string)
df['Msg'] = df['Msg'].apply(lambda x :  remove_emoji(x))
df
# Out:
#                                                      Msg  Label1  word_count
# 0      durbi garee hundishee durbummaa qabduu dhiira ...       1          11
# 1      durbif gaararraan waanuma argitetti bifasheef ...       1           7
# 2      durbummaa namni qabu hundi gagamaa addunyaan m...       1          16
# 3                               durbi safuu beektu kooti      10           5
# 4      durbummaa mataan haxxifannaan hiikatu jibbisiisam       1           6
# ...                                                  ...     ...         ...
# 12807                         caalaa dhugumaan caalaadha      40           5
# 12808  dhugaan karaatti hin haftu caaliyyee jabaadhu ...      40           8
# 12809              buli wan gumaachitu hin dhabin sanyii      40           7
# 12810                      leenca dhugaa keeti jajjabee       40           7
# 12811                             jiraadhu leenca keenya      40           4
#
# [12812 rows x 3 columns]

# %%
df.drop(['word_count'],axis='columns',inplace=True)
df
# Out:
#                                                      Msg  Label1
# 0      durbi garee hundishee durbummaa qabduu dhiira ...       1
# 1      durbif gaararraan waanuma argitetti bifasheef ...       1
# 2      durbummaa namni qabu hundi gagamaa addunyaan m...       1
# 3                               durbi safuu beektu kooti      10
# 4      durbummaa mataan haxxifannaan hiikatu jibbisiisam       1
# ...                                                  ...     ...
# 12807                         caalaa dhugumaan caalaadha      40
# 12808  dhugaan karaatti hin haftu caaliyyee jabaadhu ...      40
# 12809              buli wan gumaachitu hin dhabin sanyii      40
# 12810                      leenca dhugaa keeti jajjabee       40
# 12811                             jiraadhu leenca keenya      40
#
# [12812 rows x 2 columns]

# %%
cleaneddf=df
cleaneddf
# Out:
#                                                      Msg  Label1
# 0      durbi garee hundishee durbummaa qabduu dhiira ...       1
# 1      durbif gaararraan waanuma argitetti bifasheef ...       1
# 2      durbummaa namni qabu hundi gagamaa addunyaan m...       1
# 3                               durbi safuu beektu kooti      10
# 4      durbummaa mataan haxxifannaan hiikatu jibbisiisam       1
# ...                                                  ...     ...
# 12807                         caalaa dhugumaan caalaadha      40
# 12808  dhugaan karaatti hin haftu caaliyyee jabaadhu ...      40
# 12809              buli wan gumaachitu hin dhabin sanyii      40
# 12810                      leenca dhugaa keeti jajjabee       40
# 12811                             jiraadhu leenca keenya      40
#
# [12812 rows x 2 columns]

# %%
df['Msg'] = df['Msg'].str.replace('\d+', '')
df['Msg'].str.findall('\w{2,}').str.join(' ')
# Out:
# 0        durbi garee hundishee durbummaa qabduu dhiira ...
# 1        durbif gaararraan waanuma argitetti bifasheef ...
# 2        durbummaa namni qabu hundi gagamaa addunyaan m...
# 3                                 durbi safuu beektu kooti
# 4        durbummaa mataan haxxifannaan hiikatu jibbisiisam
#                                ...
# 12807                           caalaa dhugumaan caalaadha
# 12808    dhugaan karaatti hin haftu caaliyyee jabaadhu ...
# 12809                buli wan gumaachitu hin dhabin sanyii
# 12810                         leenca dhugaa keeti jajjabee
# 12811                               jiraadhu leenca keenya
# Name: Msg, Length: 12812, dtype: object

# %%
X_train, X_test, y_train, y_test = train_test_split(cleaneddf.Msg,df.Label1,test_size=0.2,random_state=10)

# %%
print(len(X_train))
print(len(X_test))
print(len(y_train))
print(len(y_test))
print('total '+ str(len(X_train)+len(X_test)))
# Out:
# 10249
# 2563
# 10249
# 2563
# total 12812

# %% [markdown]
# # 2.Text Vectorization/ Feature Extraction

# %% [markdown]
# ## 2.1 BOW Vectorization

# %%
# word unigram gram vectorization 
from sklearn.feature_extraction.text import CountVectorizer
vec1 = CountVectorizer(min_df=1,ngram_range=(1,1),analyzer='word')
X_train_count1 = vec1.fit_transform(X_train.values)
#X_train_count1.toarray()[:2]

# %%
X_train_count1
# Out:
# <10249x17614 sparse matrix of type '<class 'numpy.int64'>'
# 	with 82558 stored elements in Compressed Sparse Row format>

# %%
print( 'Vocabulary size ' +str(len(vec1.vocabulary_)))
# Out:
# Vocabulary size 17614

# %%
vec1.get_feature_names()
# Out:
# ['aa',
#  'aaadaa',
#  'aabb',
#  'aabba',
#  'aabbee',
#  'aabbootti',
#  'aabshir',
#  'aachuu',
#  'aada',
#  'aadaa',
#  'aadaaf',
#  'aadaafi',
#  'aadaan',
#  'aadaasaa',
#  'aadafi',
#  'aadam',
#  'aadde',
#  'aaddee',
#  'aadha',
#  'aadhaan',
#  'aadii',
#  'aadmale',
#  'aaf',
#  'aafi',
#  'aafii',
#  'aafrikaa',
#  'aagaa',
#  'aakiratillee',
#  'aaktariin',
#  'aalbeen',
#  'aalee',
#  'aalem',
#  'aalfaa',
#  'aalfaadhas',
#  'aam',
#  'aama',
#  'aame',
#  'aamiiin',
#  'aamiin',
#  'aammiin',
#  'aan',
#  'aana',
#  'aanaa',
#  'aanaaa',
#  'aanaaichaa',
#  'aanaalee',
#  'aanaan',
#  'aanga',
#  'aangeessuun',
#  'aangoo',
#  'aangoof',
#  'aangoon',
#  'aangoorra',
#  'aangoorraa',
#  'aangooti',
#  'aangootti',
#  'aangotti',
#  'aanichaa',
#  'aanii',
#  'aannaan',
#  'aannaanii',
#  'aannan',
#  'aannanii',
#  'aanni',
#  'aannis',
#  'aanolee',
#  'aanoleef',
#  'aanoleeti',
#  'aansa',
#  'aansaan',
#  'aansee',
#  'aansitee',
#  'aansuun',
#  'aantummaa',
#  'aantummaan',
#  'aantuu',
#  'aantuun',
#  'aanuf',
#  'aanutti',
#  'aanuuf',
#  'aara',
#  'aarfatiin',
#  'aarii',
#  'aariin',
#  'aarraa',
#  'aarsa',
#  'aarsaa',
#  'aarsee',
#  'aarsinaa',
#  'aarsu',
#  'aarsuuf',
#  'aartii',
#  'aartiin',
#  'aartist',
#  'aartisti',
#  'aartistootaaf',
#  'aartu',
#  'aata',
#  'aati',
#  'aatii',
#  'aatiif',
#  'aatiin',
#  'aawa',
#  'aawu',
#  'aayii',
#  'aayinaan',
#  'aayyolii',
#  'aayyoo',
#  'abaaboo',
#  'abaaramaa',
#  'abaaramaadha',
#  'abaarame',
#  'abaaramnellee',
#  'abaaramtuu',
#  'abaaramtuudha',
#  'abaare',
#  'abaarre',
#  'abaarru',
#  'abaarsa',
#  'abaarsaa',
#  'abaarsi',
#  'abaartu',
#  'abaaruu',
#  'abaaruun',
#  'ababaa',
#  'abadan',
#  'abajjee',
#  'abalu',
#  'abaramtee',
#  'abaramtuu',
#  'abashaadha',
#  'abashaan',
#  'abashaatuu',
#  'abashoonni',
#  'abba',
#  'abbaa',
#  'abbaabbuu',
#  'abbaabooraa',
#  'abbaadha',
#  'abbaaduulaa',
#  'abbaaf',
#  'abbaafi',
#  'abbaamaccaa',
#  'abbaan',
#  'abbaas',
#  'abbaati',
#  'abbaatti',
#  'abbaatu',
#  'abbabaa',
#  'abbagaar',
#  'abbatu',
#  'abbay',
#  'abbayyi',
#  'abbbaaf',
#  'abbebe',
#  'abbichuu',
#  'abbichuuf',
#  'abbichuufaa',
#  'abbichuun',
#  'abbichuuti',
#  'abbiyyi',
#  'abbo',
#  'abboo',
#  'abboomamuutiin',
#  'abboomee',
#  'abboota',
#  'abbooti',
#  'abbootii',
#  'abbootiifi',
#  'abbootiin',
#  'abbootiisaarraa',
#  'abbootin',
#  'abboottan',
#  'abboottiin',
#  'abbotii',
#  'abbotti',
#  'abbuma',
#  'abbuu',
#  'abbuuqqatanii',
#  'abdaachiisadha',
#  'abdachaa',
#  'abdadha',
#  'abdan',
#  'abdanne',
#  'abdataafaa',
#  'abdatin',
#  'abdattee',
#  'abdii',
#  'abdiidha',
#  'abdiin',
#  'abdiisaa',
#  'abdiisaan',
#  'abdoo',
#  'abdulhaakim',
#  'abebaaw',
#  'abeebee',
#  'abeebeef',
#  'abichuu',
#  'abidda',
#  'abiddaa',
#  'abiddaaf',
#  'abiddaan',
#  'abiddaati',
#  'abiddi',
#  'abin',
#  'abishee',
#  'abisiin',
#  'abiy',
#  'abiyoot',
#  'abiyyi',
#  'abiyyialaabaa',
#  'abiyyibiyya',
#  'abiyyidha',
#  'abiyyierga',
#  'abiyyif',
#  'abiyyii',
#  'abiyyiin',
#  'abiyyiinis',
#  'abiyyimaaltu',
#  'abiyyin',
#  'abiyyiy',
#  'abiyyiyi',
#  'abiyyiyis',
#  'abiyyoot',
#  'abjoota',
#  'abjootaa',
#  'abjoottuu',
#  'abjootuun',
#  'abjun',
#  'abjuu',
#  'abjuudha',
#  'abjuudhaa',
#  'abjuudhaan',
#  'abjuudhanuu',
#  'abjuun',
#  'abo',
#  'abon',
#  'aboo',
#  'abooku',
#  'abos',
#  'abraahim',
#  'abrahaam',
#  'abrihaamii',
#  'abshaaloomuu',
#  'abshaalummaan',
#  'abshalummaan',
#  'abshir',
#  'abukaatoo',
#  'abukaatoon',
#  'abuna',
#  'abune',
#  'abut',
#  'abuuratetti',
#  'abuyee',
#  'achaa',
#  'achi',
#  'achii',
#  'achin',
#  'achirra',
#  'achirraa',
#  'achitti',
#  'achumaa',
#  'achumaan',
#  'achumatti',
#  'achusaanis',
#  'achuu',
#  'achuuf',
#  'achuun',
#  'achuunsaa',
#  'achuutti',
#  'ada',
#  'adaadaa',
#  'adaadaan',
#  'adaama',
#  'adaamaa',
#  'adaamaas',
#  'adaamaatiin',
#  'adaamaatti',
#  'adaamatti',
#  'adaammii',
#  'adaanach',
#  'adaanachi',
#  'adaanech',
#  'adaba',
#  'adabadhaa',
#  'adabadhu',
#  'adabama',
#  'adabamaa',
#  'adabamuuf',
#  'adabbii',
#  'adabdan',
#  'adabee',
#  'adabu',
#  'adada',
#  'adahaa',
#  'adala',
#  'adalaa',
#  'adam',
#  'adamsamtee',
#  'adamuu',
#  'adaraa',
#  'adawaa',
#  'adawwii',
#  'adda',
#  'addaa',
#  'addaaf',
#  'addaafi',
#  'addaam',
#  'addaamii',
#  'addaan',
#  'addaarra',
#  'addaarraa',
#  'addaarratti',
#  'addaas',
#  'addaatiin',
#  'addaatti',
#  'addabaabaayii',
#  'addababayiitti',
#  'addaggee',
#  'addaggeedha',
#  'addaggeen',
#  'addaggeetti',
#  'addan',
#  'addaraasha',
#  'addarra',
#  'addas',
#  'addatti',
#  'addee',
#  'addeessarratti',
#  'addeessatti',
#  'addeessera',
#  'addi',
#  'addichaa',
#  'addisuu',
#  'addooyyeen',
#  'addummaa',
#  'addunya',
#  'addunyaa',
#  'addunyaaf',
#  'addunyaan',
#  'addunyaarraa',
#  'addunyaarratti',
#  'addunyaat',
#  'addunyaati',
#  'addunyaatiin',
#  'addunyaatis',
#  'addunyaatti',
#  'addunyaattis',
#  'addunyaraa',
#  'addunyarraa',
#  'addunyatti',
#  'addunyuma',
#  'adduunyaa',
#  'adeemaa',
#  'adeemi',
#  'adeemsa',
#  'adeemsarra',
#  'adeemsi',
#  'adeemsifamaa',
#  'adeemsifame',
#  'adeemsifamerratti',
#  'adeemsifamu',
#  'adeemsisaa',
#  'adeemu',
#  'adeemuu',
#  'adhaa',
#  'adhaan',
#  'adiin',
#  'adiiti',
#  'adiitti',
#  'adiitu',
#  'adis',
#  'adiyyootti',
#  'ado',
#  'adol',
#  'adoleessa',
#  'adoolessa',
#  'adoolessaa',
#  'adunyaa',
#  'adunyaaf',
#  'adunyaan',
#  'adurree',
#  'adurreedhan',
#  'adurreen',
#  'aduu',
#  'aduun',
#  'aduuwaa',
#  'adwaa',
#  'adwaafi',
#  'adwaan',
#  'adwaarratti',
#  'afaan',
#  'afaanicha',
#  'afaanichaatiif',
#  'afaanii',
#  'afaaniin',
#  'afaanin',
#  'afaanitti',
#  'afaanonni',
#  'afaanoonni',
#  'afaanoota',
#  'afaanota',
#  'afaansa',
#  'afaanuma',
#  'afarii',
#  'afarikaati',
#  'afariyaa',
#  'afayaa',
#  'affaar',
#  'affeeramaa',
#  'affeeramtani',
#  'affeeri',
#  'affeeruun',
#  'afgaanistaan',
#  'afgaanistaanidha',
#  'afgaanistaanii',
#  'afgaanistaaniif',
#  'afgaanistaanitti',
#  'afirikaaf',
#  'afoo',
#  'afoola',
#  'afoolaafi',
#  'afoolaan',
#  'afraash',
#  'afran',
#  'afranuu',
#  'afriikaa',
#  'afriikaafi',
#  'afrikaa',
#  'afrikaaf',
#  'afrikaafi',
#  'afrikaan',
#  'afrikaanota',
#  'afrikaanummaadha',
#  'afrikaati',
#  'afrikaatti',
#  'afroo',
#  'afuftuuu',
#  'afur',
#  'afurii',
#  'afurtama',
#  'afurtamii',
#  'afuufa',
#  'afuufaa',
#  'afuufamaa',
#  'afuufan',
#  'afuufanii',
#  'afuufe',
#  'afuuffee',
#  'afuufi',
#  'afuufticha',
#  'afuuftota',
#  'afuuftu',
#  'afuuftudha',
#  'afuuftun',
#  'afuuftuu',
#  'afuuftuudha',
#  'afuuftuun',
#  'afuuftuuti',
#  'afuuftuwwan',
#  'afuufuuf',
#  'afuura',
#  'afuurri',
#  'afxiraa',
#  'afyaa',
#  'agabuu',
#  'aganyehush',
#  'agare',
#  'agarra',
#  'agarre',
#  'agarree',
#  'agarsiifne',
#  'agarsiiftaniif',
#  'agarsiisa',
#  'agarsiisan',
#  'agarsiisaniidha',
#  'agarsiisaniif',
#  'agarsiisaniiru',
#  'agarsiisanis',
#  'agarsiise',
#  'agarsiiseefi',
#  'agarsiiseera',
#  'agarsiisu',
#  'agarsiisuf',
#  'agarsiisutti',
#  'agarsiisuu',
#  'agarsiisuuf',
#  'agarsiisuufaa',
#  'agarsiisuun',
#  'agarsisuu',
#  'agartan',
#  'agartanii',
#  'agartanitti',
#  'agarte',
#  'agartee',
#  'agarteen',
#  'agartetti',
#  'agartu',
#  'agartuu',
#  'agartuun',
#  'agawu',
#  'aggaammii',
#  'aggaaroo',
#  'agi',
#  'agrsiisaa',
#  'aguggamanee',
#  'ahii',
#  'ahimad',
#  'ahimadii',
#  'ahimadin',
#  'ahimed',
#  'ahmad',
#  'ahmed',
#  'ai',
#  'airport',
#  'ajaa',
#  'ajaab',
#  'ajaahu',
#  'ajaawa',
#  'ajaawaa',
#  'ajaawaadha',
#  'ajaayiba',
#  'ajaayibaa',
#  'ajab',
#  'ajaha',
#  'ajaja',
#  'ajajame',
#  'ajajasaati',
#  'ajaje',
#  'ajaju',
#  'ajajuun',
#  'ajandaa',
#  'ajandaan',
#  'ajandaawwan',
#  'ajawaa',
#  'ajawuuf',
#  'ajawwaa',
#  'ajeesse',
#  'ajeesuu',
#  'ajeesuun',
#  'ajeja',
#  'ajeje',
#  'ajja',
#  'ajjaba',
#  'ajjamaa',
#  'ajjechaa',
#  'ajjeecha',
#  'ajjeechaa',
#  'ajjeechaadha',
#  'ajjeechaan',
#  'ajjeechan',
#  'ajjeechisaa',
#  'ajjeefamaa',
#  'ajjeefaman',
#  'ajjeefame',
#  'ajjeefamee',
#  'ajjeefameef',
#  'ajjeefameera',
#  'ajjeefamnaan',
#  'ajjeefamte',
#  'ajjeefamu',
#  'ajjeefamuu',
#  'ajjeefamuun',
#  'ajjeefamuunsaa',
#  'ajjeeffamee',
#  'ajjeefnee',
#  'ajjeeftan',
#  'ajjeeftee',
#  'ajjeefti',
#  'ajjeesa',
#  'ajjeesaa',
#  'ajjeesaafi',
#  'ajjeesan',
#  'ajjeesani',
#  'ajjeesanii',
#  'ajjeese',
#  'ajjeesee',
#  'ajjeesi',
#  'ajjeesiftee',
#  'ajjeesiniin',
#  'ajjeesisaa',
#  'ajjeesistee',
#  'ajjeesna',
#  'ajjeesne',
#  'ajjeessa',
#  'ajjeesse',
#  'ajjeessee',
#  'ajjeessi',
#  'ajjeessun',
#  'ajjeessuu',
#  'ajjeeste',
#  'ajjeestee',
#  'ajjeesti',
#  'ajjeestu',
#  'ajjeesu',
#  'ajjeesudha',
#  'ajjeesun',
#  'ajjeesurra',
#  'ajjeesutu',
#  'ajjeesuu',
#  'ajjeesuudhaan',
#  'ajjeesuudhaani',
#  'ajjeesuudhan',
#  'ajjeesuun',
#  'ajjeesuutu',
#  'ajjeetti',
#  'ajoofne',
#  'ajooftii',
#  'ajooftota',
#  'ajooftu',
#  'ajooftuu',
#  'ajoomanii',
#  'ajuusaa',
#  'akaafaa',
#  'akaakaa',
#  'akaakayyuu',
#  'akaakayyuun',
#  'akaakuu',
#  'akeekaniiru',
#  'akeekasaaniirraa',
#  'akeekeedha',
#  'akeekeedhas',
#  'akeekkkachisaa',
#  'akeeku',
#  'akirattillee',
#  'akka',
#  'akkaa',
#  'akkaadaamii',
#  'akkaata',
#  'akkaataa',
#  'akkami',
#  'akkamii',
#  'akkamiin',
#  'akkamin',
#  'akkamitti',
#  'akkamumaadha',
#  'akkan',
#  'akkana',
#  'akkanaa',
#  'akkanaati',
#  'akkanati',
#  'akkanatti',
#  'akkanattii',
#  'akkannatti',
#  'akkanumaan',
#  'akkanumatti',
#  'akkasi',
#  'akkasii',
#  'akkasiin',
#  'akkasirraa',
#  'akkasitti',
#  'akkasittiin',
#  'akkasumaan',
#  'akkataa',
#  'akkatti',
#  'akkatuma',
#  'akkkeessa',
#  'akkkuma',
#  'akliluu',
#  'akoo',
#  'akraa',
#  'aktiivistoonni',
#  'aktivistii',
#  'aktivistoonni',
#  'aktivistoota',
#  'akuma',
#  'al',
#  'alaa',
#  'alaaba',
#  'alaabaa',
#  'alaabaan',
#  'alaaf',
#  'alaaki',
#  'alaakti',
#  'alaan',
#  'alaanfata',
#  'alaarratti',
#  'alaattis',
#  'alaba',
#  'alabaa',
#  'alabateetii',
#  'alagaa',
#  'alagaaf',
#  'alagaan',
#  'alagaarraa',
#  'alagaati',
#  'alagaatin',
#  'alaguma',
#  'alahamdulilah',
#  'alahamdulillah',
#  'alalleen',
#  'alamaayyoo',
#  'alamin',
#  'alamuu',
#  'alana',
#  'alba',
#  'albaadhessa',
#  'albaata',
#  'albaataa',
#  'albaatee',
#  'albaatettaa',
#  'albaati',
#  'albaatidha',
#  'albaatii',
#  'albaatiidha',
#  'albaatu',
#  'albaatuu',
#  'albahee',
#  'albee',
#  'albeen',
#  'aleeyhi',
#  'aleykum',
#  'ali',
#  'alii',
#  'aliidha',
#  'aliin',
#  'aliyyii',
#  'alkallattiin',
#  'allaah',
#  'allaaha',
#  'allaahmdulillah',
#  'allaahti',
#  'allaas',
#  'allaattii',
#  'allah',
#  'allahamdulillah',
#  'allahmdulillah',
#  'allhamdulillah',
#  'almaaz',
#  'alminash',
#  'altakkatti',
#  'altokkkotti',
#  'am',
#  'ama',
#  'amaa',
#  'amaaaras',
#  'amaanaa',
#  'amaanaan',
#  'amaanta',
#  'amaantillee',
#  'amaanu',
#  'amaaqixa',
#  'amaara',
#  'amaaraa',
#  'amaaraadha',
#  'amaaraaf',
#  'amaaraafi',
#  'amaaraan',
#  'amaaraas',
#  'amaaraati',
#  'amaaraatif',
#  'amaaraatii',
#  'amaaraatiin',
#  'amaaraatti',
#  'amaaraatu',
#  'amaaradha',
#  'amaaras',
#  'amaarati',
#  'amaaratin',
#  'amaaratti',
#  'amaaratu',
#  'amaariffa',
#  'amaariffaa',
#  'amaarii',
#  'amaaronni',
#  'amaaroonni',
#  'amaarota',
#  'amaarri',
#  'amaarris',
#  'amaarti',
#  'amaartonni',
#  'amaaruma',
#  'amaarummaa',
#  'amaazon',
#  'amaj',
#  'amajji',
#  'amajjii',
#  'amala',
#  'amalaa',
#  'amalashee',
#  'amalli',
#  'amaloota',
#  'amamantii',
#  'aman',
#  'amana',
#  'amanaa',
#  'amanadhaa',
#  'amanama',
#  'amanamaa',
#  'amanamne',
#  'amanamti',
#  'amanamtu',
#  'amanamtuu',
#  'amanamtuun',
#  'amanamummaa',
#  'amanamummaadha',
#  'amanamummaan',
#  'amanamuuf',
#  'amanamuun',
#  'amanan',
#  'amananii',
#  'amananiidha',
#  'amananiif',
#  'amanataa',
#  'amanatan',
#  'amane',
#  'amanee',
#  'amaneef',
#  'amani',
#  'amanii',
#  'amaniin',
#  'amaniinaa',
#  'amaniiru',
#  'amanin',
#  'amaninaa',
#  'amanitiin',
#  'amanna',
#  'amanne',
#  'amannee',
#  'amannu',
#  'amansiisaan',
#  'amansiisi',
#  'amansiisuu',
#  'amanta',
#  'amantaa',
#  'amantaafi',
#  'amantaalee',
#  'amantaaleen',
#  'amantaan',
#  'amantaas',
#  'amantaasaaniitti',
#  'amantaatiin',
#  'amantaatti',
#  'amantan',
#  'amantarraa',
#  'amantee',
#  'amantees',
#  'amantes',
#  'amanti',
#  'amanticha',
#  'amantichaa',
#  'amantichaaf',
#  'amantichaati',
#  'amantichi',
#  'amantii',
#  'amantiidha',
#  'amantiifi',
#  'amantiilee',
#  'amantiin',
#  'amantiis',
#  'amantiitin',
#  'amantiitinillee',
#  'amantiitti',
#  'amantiiwwan',
#  'amantinis',
#  'amantoonni',
#  'amantoota',
#  'amantootaa',
#  'amantootaatis',
#  'amantu',
#  'amantus',
#  'amantuus',
#  'amantuyyuu',
#  'amanu',
#  'amanudha',
#  'amanun',
#  'amanuu',
#  'amanuudha',
#  'amanuuf',
#  'amanuun',
#  'amara',
#  'amaraa',
#  'amariffaa',
#  'amarri',
#  'amarrii',
#  'amaruma',
#  'amataa',
#  'amayyuu',
#  'ambaa',
#  'ambaachaw',
#  'ambaachoo',
#  'ambaarraa',
#  'ambaxxaa',
#  'amboo',
#  'amboon',
#  'amboorran',
#  'ambootis',
#  'ambootti',
#  'ame',
#  'amee',
#  'ameen',
#  'ameera',
#  'ameerikaa',
#  'ameerikaan',
#  'ameerikaatti',
#  'amerikaa',
#  'amerratti',
#  'ametti',
#  'amhaara',
#  'amhaarota',
#  'amiin',
#  'aministiin',
#  'amir',
#  'amma',
#  'ammaa',
#  'ammaaf',
#  'ammaalle',
#  'ammaan',
#  'ammaatti',
#  'ammaattis',
#  'ammaatu',
#  'ammaayyuu',
#  'ammachuu',
#  'ammadha',
#  'ammallee',
#  'ammammoo',
#  'ammamoo',
#  'amman',
#  'ammantii',
#  'ammarra',
#  'ammarraa',
#  'ammarri',
#  'ammas',
#  'ammatti',
#  'ammayya',
#  'ammayyaa',
#  'ammayyaaf',
#  'ammayyaan',
#  'ammayyaatin',
#  'ammayyeessuun',
#  'ammayyuu',
#  'ammllee',
#  'ammuma',
#  'amne',
#  'amni',
#  'amntaan',
#  'amntichaa',
#  'amta',
#  'amtee',
#  'amu',
#  'amurratti',
#  'amus',
#  'amuu',
#  'amuun',
#  'amuus',
#  'an',
#  'ana',
#  'anaallen',
#  'anallee',
#  'anatu',
#  'andu',
#  'anduu',
#  'anfarroo',
#  'angaayootni',
#  'angafa',
#  'angafaa',
#  'angafaati',
#  'angawoonni',
#  'angela',
#  'angoo',
#  'ani',
#  'anii',
#  'aniif',
#  'aniifi',
#  'aniifii',
#  'aniin',
#  'aniiniifi',
#  'aniiru',
#  'aniis',
#  'aniituma',
#  'anileyyi',
#  'anillee',
#  'animmo',
#  'animmoo',
#  'anis',
#  'anitaa',
#  'anna',
#  'annaa',
#  'anne',
#  'annee',
#  'anniisaa',
#  'anniyyaadhaan',
#  'annuu',
#  'anoo',
#  'anoole',
#  'antaartikaatti',
#  'anteenaa',
#  'anuma',
#  'anuu',
#  'appii',
#  'aqaaqii',
#  'araada',
#  'araadaa',
#  'araara',
#  'araaraa',
#  'araaraafi',
#  'araaraatis',
#  'araaraman',
#  'araaramaniyyuu',
#  'araarami',
#  ...]

# %% [markdown]
# # 2.2 TF-IDF Vectorization `

# %%
#  tfidf vectorization ways 1 by ngram 
from sklearn.feature_extraction.text import TfidfVectorizer
tfidfvec1=TfidfVectorizer(min_df=1,ngram_range=(1,1),analyzer='word')
X_train_tfidf1=tfidfvec1.fit_transform(X_train.values)
#X_train_tfidf1.toarray()[:2]

# %% [markdown]
# # 3. Machine learnig algorithm

# %% [markdown]
# # 3.1 BernoulliNB  Algorithm

# %%
# Naive Bayes Algorithm 1 by ngram 
from sklearn.naive_bayes import MultinomialNB
nbmodel1 = MultinomialNB(alpha=1.0, fit_prior=True, class_prior=None)
nbmodel1.fit(X_train_count1,y_train)
# Out:
# MultinomialNB()

# %%
# Naive Bayes Algorithm 1 by TF-IDF with unigram 
from sklearn.naive_bayes import MultinomialNB
nbmodel2 = MultinomialNB(alpha=1.0, fit_prior=True, class_prior=None)
nbmodel2.fit(X_train_tfidf1,y_train)
# Out:
# MultinomialNB()

# %% [markdown]
# # 4. Prediction

# %% [markdown]
# # 4.1 Prediction by NB

# %%
# Prediction by first model 
post_or_comment  = [
    'durbi diimtuun cimtuudha  ',
    'shammarran  wallaggaa Fokkistuudha',
    'Oromoon Beekadha ',
    'Oromoon sirna Gadaan Bula ' ,
    'biyya koo nin jibba',
    'Uummanni Amaaraa diina uummata Oromooti',
    'Tiruump nama gowwadha',
    'Uummanni Gurraachi sammuun isaanii hin yaadu',
    'Mootumman wayyaanee Qabeenya biyyaa saame',
    'Beqee haadha keeti icci'
    
]
m1 = vec1.transform(post_or_comment)
nbmodel1.predict(m1)
# Out:
# array([ 1, 10, 30, 30, 20,  3,  3,  4, 30,  4], dtype=int64)

# %%
# Prediction by fourth model 
post_or_comment  = [
    'durbi diimtuun cimtuudha  ',
    'shammarran  wallaggaa Fokkistuudha',
    'Oromoon Beekadha ',
    'Oromoon sirna Gadaan Bula ' ,
    'biyya koo nin jibba',
    'Uummanni Amaaraa diina uummata Oromooti',
    'Tiruump nama gowwadha',
    'Uummanni Gurraachi sammuun isaanii hin yaadu'
    'Mootumman wayyaanee Qabeenya biyyaa saame',
    'Beqee haadha keeti icci'
    
]
m4 = tfidfvec1.transform(post_or_comment)
nbmodel2.predict(m4)
# Out:
# array([ 1, 10, 30, 30, 20,  3,  3,  3,  4], dtype=int64)

# %% [markdown]
# # 5.1 Accuracy by NB

# %%
#NB model1 
X_test_count1 = vec1.transform(X_test)
nbmodel1.score(X_test_count1, y_test)
# Out:
# 0.795942255169723

# %%
#NB model4
X_test_count2 = tfidfvec1.transform(X_test)
nbmodel2.score(X_test_count2, y_test)
# Out:
# 0.7986734295747171

# %%
# Accuracy by first model 
from sklearn.metrics import classification_report
predictions1=nbmodel1.predict(X_test_count1)
print (classification_report(y_test, predictions1))
# Out:
#               precision    recall  f1-score   support
#
#            1       0.73      0.85      0.78       301
#            2       0.73      0.82      0.77       305
#            3       0.78      0.84      0.81       408
#            4       0.82      0.83      0.83       320
#           10       0.86      0.69      0.76       354
#           20       0.82      0.74      0.78       302
#           30       0.76      0.75      0.76       280
#           40       0.92      0.85      0.88       293
#
#     accuracy                           0.80      2563
#    macro avg       0.80      0.80      0.80      2563
# weighted avg       0.80      0.80      0.80      2563

# %%
# Accuracy by first model 
from sklearn.metrics import classification_report
predictions1=nbmodel2.predict(X_test_count2)
print (classification_report(y_test, predictions1))
# Out:
#               precision    recall  f1-score   support
#
#            1       0.75      0.84      0.79       301
#            2       0.76      0.75      0.76       305
#            3       0.73      0.89      0.80       408
#            4       0.78      0.86      0.82       320
#           10       0.84      0.74      0.79       354
#           20       0.82      0.75      0.78       302
#           30       0.84      0.68      0.75       280
#           40       0.93      0.86      0.89       293
#
#     accuracy                           0.80      2563
#    macro avg       0.81      0.79      0.80      2563
# weighted avg       0.80      0.80      0.80      2563

# %% [markdown]
# # Confusion Matrix

# %%
# Generate confusion matrix
from sklearn.metrics import plot_confusion_matrix
fig, ax = plt.subplots(figsize=(8, 8))
matrix = plot_confusion_matrix(nbmodel1, X_test_count1, y_test,
                                 cmap=plt.cm.Blues,
                                 ax=ax,
                                normalize='true')
plt.title('Confusion matrix for NB by BOW')
plt.show(matrix)
plt.show()

# %%
# Generate confusion matrix
from sklearn.metrics import plot_confusion_matrix
fig, ax = plt.subplots(figsize=(8, 8))
matrix = plot_confusion_matrix(nbmodel2, X_test_count2, y_test,
                                 cmap=plt.cm.Blues,
                                 ax=ax,
                                normalize='true')
plt.title('Confusion matrix for NB by BOW')
plt.show(matrix)
plt.show()

# %% [markdown]
# # Saving model for later use

# %%
import pickle 
with open('model folder/nbmodel18','wb') as f:
    pickle.dump(nbmodel1,f)

# %%
import pickle 
with open('model folder/nbmodel28','wb') as f:
    pickle.dump(nbmodel2,f)
